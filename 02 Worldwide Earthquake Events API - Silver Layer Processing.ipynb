# %% [markdown]
# ## Worldwide Earthquake Events API - Silver Layer Processing

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
# Out:
# StatementMeta(, 89294237-173f-4beb-bb04-8e22e5dbcfc5, 11, Finished, Available, Finished)

# %% [markdown]
# ### Importing JSON Dataset

# %%
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake.json")
# Out:
# StatementMeta(, 89294237-173f-4beb-bb04-8e22e5dbcfc5, 10, Finished, Available, Finished)

# %% [markdown]
# ### Extractng the key attributes from the earthquake dataset

# %%
df = \
df.\
    select(
        'id',
        col('geometry.coordinates').getItem(0).alias('longitude'),
        col('geometry.coordinates').getItem(1).alias('latitude'),
        col('geometry.coordinates').getItem(2).alias('elevation'),
        col('properties.title').alias('title'),
        col('properties.place').alias('place_description'),
        col('properties.sig').alias('sig'),
        col('properties.mag').alias('mag'),
        col('properties.magType').alias('magType'),
        col('properties.time').alias('time'),
        col('properties.updated').alias('updated')
    )
# Out:
# StatementMeta(, 89294237-173f-4beb-bb04-8e22e5dbcfc5, 12, Finished, Available, Finished)

# %% [markdown]
# ### Converting time and updated the columns from miliseconds to time timestamp format

# %%
df = df.\
    withColumn('time', col('time')/1000).\
    withColumn('updated', col('updated')/1000).\
    withColumn('time', col('time').cast(TimestampType())).\
    withColumn('updated', col('updated').cast(TimestampType()))
# Out:
# StatementMeta(, 89294237-173f-4beb-bb04-8e22e5dbcfc5, 13, Finished, Available, Finished)

# %% [markdown]
# ### Updating the data to the silver table

# %%
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, 89294237-173f-4beb-bb04-8e22e5dbcfc5, 14, Finished, Available, Finished)
